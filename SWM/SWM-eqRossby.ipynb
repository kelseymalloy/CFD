# %% [markdown]
# # Shallow water model
# ## HW3
# ### Kelsey Malloy
#
#
# ### <i>last edited: 11/2020</i>

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from Diagnostics import calc_budget, avg_x, avg_y, d_dx, d_dy
from RKPackage import RK3Step 
from SWE_RHS import SWE_RHS
from Plotting import DefinePlot, UpdatePlots
from IC_BC import gauss,wave,BC,wave_channel,RossbyIC

# %% [markdown]
# ### Set geometry

# %%
nx = 48*8 # number of x pts
ny = 16*8 # number of y pts
lx = 48 # length of x
ly = 16 # length of y
dx = float(lx)/nx # distance between x pts
dy = float(ly)/ny # distance between y pts
dxx = dx
dyy = dy
print(dx,dy,dxx,dyy)

# centered grid -- p points
xc = (-lx/2)+np.arange(nx)*(dx)
yc = (-ly/2)+np.arange(ny)*(dy)
XP,YP = np.meshgrid(xc,yc)
print('Centered grid shape (pressure points): ',XP.shape)

# x-staggered grid -- u points
xstag = ((-lx/2)-dx/2)+np.arange(nx+1)*dx
print(xc[:2],xc[-2:],xstag[:2],xstag[-2:])
XU,YU = np.meshgrid(xstag,yc)
print('X-staggered grid shape (u points): ',XU.shape)

# y-staggered grid -- v points
ystag = ((-ly/2)-dy/2)+np.arange(ny+1)*dy
print(yc[:2],yc[-2:],ystag[:2],ystag[-2:])
XV,YV = np.meshgrid(xc,ystag)
print('Y-staggered grid shape (v points): ',XV.shape)

# x-staggered and y-staggered -- z points
XZ,YZ = np.meshgrid(xstag,ystag)
print('X- and Y-staggered grid shape (vort points): ',XZ.shape)
# Out:
# 0.125 0.125 0.125 0.125
# Centered grid shape (pressure points):  (128, 384)
# [-24.    -23.875] [23.75  23.875] [-24.0625 -23.9375] [23.8125 23.9375]
# X-staggered grid shape (u points):  (128, 385)
# [-8.    -7.875] [7.75  7.875] [-8.0625 -7.9375] [7.8125 7.9375]
# Y-staggered grid shape (v points):  (129, 384)
# X- and Y-staggered grid shape (vort points):  (129, 385)

# %%
plt.plot(XP[:10,:10],YP[:10,:10],'k.')
plt.plot(XU[:10,:10],YU[:10,:10],'ro')
plt.plot(XV[:10,:10],YV[:10,:10],'b+')
plt.plot(XZ[:10,:10],YZ[:10,:10],'kx')
plt.show()

# %% [markdown]
# ### Set parameters

# %%
g=1.
depth = 1.

# %% [markdown]
# ### Set time step and interval

# %%
nt = 8000+1 # number of timesteps
dt = .01 # timestep interval
CFDtest =  0.1*min(dxx, dyy)/np.sqrt(g*depth) # test to see if dt is less than CFD limit
print(CFDtest,dt)
print(nt*dt)
snapfreq = 100 # how often to plot or print energy/enstrophy
print('How many time steps will plot (not including IC): ',(nt-1)/snapfreq)
# Out:
# [[0.0125 0.0125 0.0125 ... 0.0125 0.0125 0.0125]
#  [0.0125 0.0125 0.0125 ... 0.0125 0.0125 0.0125]
#  [0.0125 0.0125 0.0125 ... 0.0125 0.0125 0.0125]
#  ...
#  [0.0125 0.0125 0.0125 ... 0.0125 0.0125 0.0125]
#  [0.0125 0.0125 0.0125 ... 0.0125 0.0125 0.0125]
#  [0.0125 0.0125 0.0125 ... 0.0125 0.0125 0.0125]] 0.01
# 80.01
# How many time steps will plot (not including IC):  80.0

# %% [markdown]
# ### Initial conditions

# %%
# initialize arrays
p = np.zeros((int(nt),ny,nx))
u = np.zeros((int(nt),ny,nx+1))
v = np.zeros((int(nt),ny+1,nx))
z = np.zeros((int(nt),ny+1,nx+1))
depth = depth + np.zeros((ny,nx))
f = YZ#np.zeros((ny+1,nx+1))

print(p.shape,depth.shape)
print(u.shape,v.shape)
print(z.shape,f.shape)
# Out:
# (8001, 128, 384) (128, 384)
# (8001, 128, 385) (8001, 129, 384)
# (8001, 129, 385) (129, 385)

# %%
# standing wave
p[0],u[0],v[0] = RossbyIC(p[0],u[0],v[0],XP,YP,0.395)

UpdatePlots(0,p[0],u[0],v[0],XP,YP,XU,YU,XV,YV)

# %%
# initial budget
V0,energy0, enstrophy0 = calc_budget(p[0],u[0],v[0],depth+p[0],f,g,dxx,dyy)

print('Initial Energy: ',np.max(energy0))
print('Initial Enstrophy: ',np.max(enstrophy0))
print('Initial Volume: ',np.max(V0))
# Out:
# Initial Energy:  63.003906250012136
# Initial Enstrophy:  4.065413056779095
# Initial Volume:  0.04400454826987746

# %% [markdown]
# ### Iterations

# %%
for it in range(nt-1):
    p[it+1],u[it+1],v[it+1] = RK3Step(p[it],u[it],v[it],f,depth,g,dxx,dyy,dt)
    BC(u[it+1],v[it+1])
    #print(u[it+1,:,-1])
    if (it%snapfreq == 0):
        # diagnostics
        V,energy,enstrophy = calc_budget(p[it+1],u[it+1],v[it+1],depth+p[it+1],f,g,dxx,dyy)
        print(it+1)
        print('\u0394Energy: ',np.max(energy)-np.max(energy0))
        print('\u0394Enstrophy: ',np.max(enstrophy)-np.max(enstrophy0))
        print('\u0394Volume: ',np.max(V)-np.max(V0))

        # plot solution
        UpdatePlots(it,p[it+1],u[it+1],v[it+1],XP,YP,XU,YU,XV,YV)
# Out:
# 1
# ΔEnergy:  9.947598300641403e-14
# ΔEnstrophy:  0.0
# ΔVolume:  1.5222202471666668e-05
# 101
# ΔEnergy:  -5.229594535194337e-12
# ΔEnstrophy:  2.5757174171303632e-14
# ΔVolume:  0.008560066721876973
# 201
# ΔEnergy:  -3.289812866569264e-12
# ΔEnstrophy:  5.062616992290714e-14
# ΔVolume:  0.014423030950523635
# 301
# ΔEnergy:  -4.376943252282217e-12
# ΔEnstrophy:  7.549516567451064e-14
# ΔVolume:  0.011382228138302447
# 401
# ΔEnergy:  4.938272013532696e-12
# ΔEnstrophy:  1.0036416142611415e-13
# ΔVolume:  0.005655229575136672
# 501
# ΔEnergy:  2.1336177269404288e-10
# ΔEnstrophy:  1.2612133559741778e-13
# ΔVolume:  0.011171181191171678
# 601
# ΔEnergy:  4.80731898733211e-10
# ΔEnstrophy:  1.5187850976872141e-13
# ΔVolume:  0.01774849079958691
# 701
# ΔEnergy:  1.332731471848092e-07
# ΔEnstrophy:  1.758593271006248e-13
# ΔVolume:  0.013576805855737652
# 801
# ΔEnergy:  1.7952096342810364e-06
# ΔEnstrophy:  2.0161650127192843e-13
# ΔVolume:  0.010236255612087297
# 901
# ΔEnergy:  7.646001584760143e-06
# ΔEnstrophy:  2.255973186038318e-13
# ΔVolume:  0.016455404463633583
# 1001
# ΔEnergy:  3.1401224632077174e-05
# ΔEnstrophy:  2.5135449277513544e-13
# ΔVolume:  0.018889214370737595
# 1101
# ΔEnergy:  9.371542530089982e-05
# ΔEnstrophy:  2.7711166694643907e-13
# ΔVolume:  0.016747667586071394
# 1201
# ΔEnergy:  0.00010620468785305093
# ΔEnstrophy:  3.019806626980426e-13
# ΔVolume:  0.014720873198646484
# 1301
# ΔEnergy:  7.44619034378502e-05
# ΔEnstrophy:  3.277378368693462e-13
# ΔVolume:  0.0180329161958045
# 1401
# ΔEnergy:  0.00012000732680661486
# ΔEnstrophy:  3.526068326209497e-13
# ΔVolume:  0.02131790899732977
# 1501
# ΔEnergy:  0.00021603157738780965
# ΔEnstrophy:  3.774758283725532e-13
# ΔVolume:  0.018374594779275284
# 1601
# ΔEnergy:  0.00026697684950960365
# ΔEnstrophy:  4.0323300254385686e-13
# ΔVolume:  0.017058173549823655
# 1701
# ΔEnergy:  0.0002292664763174912
# ΔEnstrophy:  4.2810199829546036e-13
# ΔVolume:  0.019603429866124414
# 1801
# ΔEnergy:  0.00015669097742687654
# ΔEnstrophy:  4.53859172466764e-13
# ΔVolume:  0.021217290429797572
# 1901
# ΔEnergy:  0.00011806013456094888
# ΔEnstrophy:  4.787281682183675e-13
# ΔVolume:  0.019993088196671005
# 2001
# ΔEnergy:  0.00021698197550534815
# ΔEnstrophy:  5.044853423896711e-13
# ΔVolume:  0.017757587042715683
# 2101
# ΔEnergy:  0.00025866694850407157
# ΔEnstrophy:  5.293543381412746e-13
# ΔVolume:  0.019868139749741068
# 2201
# ΔEnergy:  0.00027593580033880016
# ΔEnstrophy:  5.542233338928781e-13
# ΔVolume:  0.021400711053392585
# 2301
# ΔEnergy:  0.0006500955473356385
# ΔEnstrophy:  5.799805080641818e-13
# ΔVolume:  0.019752572550870096
# 2401
# ΔEnergy:  0.004003104646002953
# ΔEnstrophy:  6.057376822354854e-13
# ΔVolume:  0.018549810600134956
# 2501
# ΔEnergy:  0.01959325280854074
# ΔEnstrophy:  6.306066779870889e-13
# ΔVolume:  0.01929122989458333
# 2601
# ΔEnergy:  0.07759488163443962
# ΔEnstrophy:  6.545874953189923e-13
# ΔVolume:  0.020862273656947622
# 2701
# ΔEnergy:  0.24723313141366532
# ΔEnstrophy:  6.812328479099961e-13
# ΔVolume:  0.019896602307288264
# 2801
# ΔEnergy:  0.5956871689052221
# ΔEnstrophy:  7.052136652418994e-13
# ΔVolume:  0.018076847565319992
# 2901
# ΔEnergy:  1.0062294934003972
# ΔEnstrophy:  7.309708394132031e-13
# ΔVolume:  0.01910735891577657
# 3001
# ΔEnergy:  1.2403371953458304
# ΔEnstrophy:  7.567280135845067e-13
# ΔVolume:  0.020113675462061165
# 3101
# ΔEnergy:  1.1827448873339392
# ΔEnstrophy:  7.815970093361102e-13
# ΔVolume:  0.019429572933913467
# 3201
# ΔEnergy:  1.0037234162366104
# ΔEnstrophy:  8.064660050877137e-13
# ΔVolume:  0.018244395275767746
# 3301
# ΔEnergy:  1.0039453150214257
# ΔEnstrophy:  8.331113576787175e-13
# ΔVolume:  0.018286857417635645
# 3401
# ΔEnergy:  1.0039486619761249
# ΔEnstrophy:  8.57980353430321e-13
# ΔVolume:  0.019493882919076888
# 3501
# ΔEnergy:  1.0036602512241615
# ΔEnstrophy:  8.837375276016246e-13
# ΔVolume:  0.01890080021290498
# 3601
# ΔEnergy:  1.00293691301097
# ΔEnstrophy:  9.086065233532281e-13
# ΔVolume:  0.01920749875625964
# 3701
# ΔEnergy:  1.0031070542505063
# ΔEnstrophy:  9.325873406851315e-13
# ΔVolume:  0.01726873627075684
# 3801
# ΔEnergy:  1.0030956209967172
# ΔEnstrophy:  9.592326932761353e-13
# ΔVolume:  0.020571211224524752
# 3901
# ΔEnergy:  1.002647827997805
# ΔEnstrophy:  9.849898674474389e-13
# ΔVolume:  0.02086986181526357
# 4001
# ΔEnergy:  1.0025721746769278
# ΔEnstrophy:  1.0089706847793423e-12
# ΔVolume:  0.015920724460617555
# 4101
# ΔEnergy:  1.0030171045368803
# ΔEnstrophy:  1.035616037370346e-12
# ΔVolume:  0.020135780685315824
# 4201
# ΔEnergy:  1.0031702105586504
# ΔEnstrophy:  1.0604850331219495e-12
# ΔVolume:  0.01590371917392456
# 4301
# ΔEnergy:  1.002494116956143
# ΔEnstrophy:  1.0862422072932532e-12
# ΔVolume:  0.02046684077158538
# 4401
# ΔEnergy:  1.0025910753603
# ΔEnstrophy:  1.1111112030448567e-12
# ΔVolume:  0.01543491877295055
# 4501
# ΔEnergy:  1.0026176429234397
# ΔEnstrophy:  1.13509202037676e-12
# ΔVolume:  0.0189927950908656
# 4601
# ΔEnergy:  1.0758082229589974
# ΔEnstrophy:  1.1617373729677638e-12
# ΔVolume:  0.016208981206727473
# 4701
# ΔEnergy:  1.1045613401621495
# ΔEnstrophy:  1.1866063687193673e-12
# ΔVolume:  0.019032701498325005
# 4801
# ΔEnergy:  1.1243442446569532
# ΔEnstrophy:  1.212363542890671e-12
# ΔVolume:  0.015682157667947887
# 4901
# ΔEnergy:  1.1962821531624712
# ΔEnstrophy:  1.2372325386422744e-12
# ΔVolume:  0.01697127814938726
# 5001
# ΔEnergy:  1.2404422394060077
# ΔEnstrophy:  1.262989712813578e-12
# ΔVolume:  0.015525898720991506
# 5101
# ΔEnergy:  1.8477751533909839
# ΔEnstrophy:  1.2878587085651816e-12
# ΔVolume:  0.01569702176702594
# 5201
# ΔEnergy:  1.3724287452385227
# ΔEnstrophy:  1.3136158827364852e-12
# ΔVolume:  0.013531587013639823
# 5301
# ΔEnergy:  1.4327805767407256
# ΔEnstrophy:  1.3393730569077889e-12
# ΔVolume:  0.012126446571955607
# 5401
# ΔEnergy:  1.498516511003487
# ΔEnstrophy:  1.3642420526593924e-12
# ΔVolume:  0.010703851479017305
# 5501
# ΔEnergy:  1.5720359381237614
# ΔEnstrophy:  1.389999226830696e-12
# ΔVolume:  0.02058252831063763
# 5601
# ΔEnergy:  1.6450259100202942
# ΔEnstrophy:  1.4157564010019996e-12
# ΔVolume:  0.045037684244411944
# 5701
# ΔEnergy:  1.7161435023834741
# ΔEnstrophy:  1.4415135751733033e-12
# ΔVolume:  0.07032490703963769
# 5801
# ΔEnergy:  1.786283048388512
# ΔEnstrophy:  1.4672707493446069e-12
# ΔVolume:  0.09468234205807835
# 5901
# ΔEnergy:  1.8522828402765015
# ΔEnstrophy:  1.4930279235159105e-12
# ΔVolume:  0.11729591637311024
# 6001
# ΔEnergy:  1.911803876037638
# ΔEnstrophy:  1.5187850976872141e-12
# ΔVolume:  0.13944104624321466
# 6101
# ΔEnergy:  1.9616483006393253
# ΔEnstrophy:  1.5445422718585178e-12
# ΔVolume:  0.16511875310772142
# 6201
# ΔEnergy:  2.0018692290692286
# ΔEnstrophy:  1.5702994460298214e-12
# ΔVolume:  0.19442615194320675
# 6301
# ΔEnergy:  2.034809683880738
# ΔEnstrophy:  1.595168441781425e-12
# ΔVolume:  0.21907182571374265
# 6401
# ΔEnergy:  2.0635828982555324
# ΔEnstrophy:  1.6209256159527285e-12
# ΔVolume:  0.23208238112393323
# 6501
# ΔEnergy:  2.0887587220587136
# ΔEnstrophy:  1.644906433284632e-12
# ΔVolume:  0.2749755567593376
# 6601
# ΔEnergy:  2.1099854571503442
# ΔEnstrophy:  1.6706636074559356e-12
# ΔVolume:  0.32056577318305957
# 6701
# ΔEnergy:  2.1262680364912683
# ΔEnstrophy:  1.694644424787839e-12
# ΔVolume:  0.3604869826502479
# 6801
# ΔEnergy:  2.1371740207363246
# ΔEnstrophy:  1.7204015989591426e-12
# ΔVolume:  0.40836571012714573
# 6901
# ΔEnergy:  2.1419141104405384
# ΔEnstrophy:  1.7461587731304462e-12
# ΔVolume:  0.45125035817114245
# 7001
# ΔEnergy:  19.99965973467623
# ΔEnstrophy:  1.7710277688820497e-12
# ΔVolume:  0.4619482693591582
# 7101
# ΔEnergy:  8.569173754586714
# ΔEnstrophy:  1.7967849430533533e-12
# ΔVolume:  0.4939647433055442
# 7201
# ΔEnergy:  15.783845703385907
# ΔEnstrophy:  1.821653938804957e-12
# ΔVolume:  0.5005183201851168
# 7301
# ΔEnergy:  21.254581300382938
# ΔEnstrophy:  1.8465229345565604e-12
# ΔVolume:  0.4953140382714122
# 7401
# ΔEnergy:  6.187998747916396
# ΔEnstrophy:  1.872280108727864e-12
# ΔVolume:  0.5059846478997164
# 7501
# ΔEnergy:  2.0782930823673667
# ΔEnstrophy:  1.8971491044794675e-12
# ΔVolume:  0.5043216595512208
# 7601
# ΔEnergy:  2.085414085527418
# ΔEnstrophy:  1.922906278650771e-12
# ΔVolume:  0.49386349686859765
# 7701
# ΔEnergy:  8.909212269561237
# ΔEnstrophy:  1.9477752744023746e-12
# ΔVolume:  0.47719227395230235
# 7801
# ΔEnergy:  15.672180999518062
# ΔEnstrophy:  1.972644270153978e-12
# ΔVolume:  0.44805023906368613
# 7901
# ΔEnergy:  26.48419872178151
# ΔEnstrophy:  1.9975132659055816e-12
# ΔVolume:  0.4579058205110954
